# %%
import gym
import matplotlib.pyplot as plt
from utils import get_item_index
import numpy as np
import run

# %%
NUM_EPISODES = 5
MAX_STEPS = 100
PATH = 'kb.pl'
RISK_THRESHOLD=50# when the agent feels it's not healthy anymore
MONEY_THRESHOLD=1
MONEY=40
ARROWS= 2
ARROWS_THRESHOLD=4

# %%
des_file,_ = run.completemapdes(1,20)
env = gym.make("MiniHack-Skill-Custom-v0",
                        character="Agent-cav-hum-neu-mal",
                        observation_keys=('screen_descriptions','inv_strs','blstats','message','pixel','chars','inv_oclasses','glyphs'),
                        wizard = True,
                        max_episode_steps = MAX_STEPS ,
                        options =(
                            "color",  # Display color for different monsters, objects, etc
                            "showexp",  # Display the experience points on the status line
                            "nobones",  # Disallow saving and loading bones files
                            "nolegacy",  # Not display an introductory message when starting the game
                            "nocmdassist",  # No command assistance
                            "disclose:+i +a +v +g +c +o",  # End of game prompt replies
                            "runmode:teleport",  # Update the map after movement has finished
                            "mention_walls",  # Give feedback when walking against a wall
                            "nosparkle",  # Not display sparkly effect for resisted magical attacks
                            "showscore",  # Shows approximate accumulated score on the bottom line
                            "race:dwa","gender:mal","align:neu","role:cav",
                            "!autopickup",
                            "pettype:none",
                        ),
                        des_file=des_file,
                )
obs = env.reset(wizkit_items = ['dwarven spear','chain mail','a healing potion','6 potion of confusion'])
env.render()
# Out:
# Your movements are slowed slightly because of your load.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:18/** Dx:12 Co:20 In:9 Wi:11 Ch:10 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:8 Xp:1/0 Burdened
# Warning: NetHack asked for env variable USER
# Warning: NetHack asked for env variable SPCODER_MAX_RUNTIME

# %%
obs,_,_,_ = env.step(78)
env.render()
obs,_,_,_ = env.step(env.actions.index(ord('f')))
env.render()
# Out:
# What do you want to wield? [- abf or ?*]
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:18/** Dx:12 Co:20 In:9 Wi:11 Ch:10 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:8 Xp:1/0 Burdened
#
# The dwarvish spear welds itself to your hand!
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:18/** Dx:12 Co:20 In:9 Wi:11 Ch:10 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:8 Xp:1/0 Burdened

# %%
#27 to drop
#69 takeoff
#77 wear

#fill_item_map(obs)
#print(get_item_index(obs,'leather armor'))

#unequip current and drop it
#obs,_,_,_= env.step(69)
#env.render()
#obs,_,_,_= env.step(27)
#env.render()
obs,_,_,_ = env.step(env.actions.index(drop_item('chain mail')))
env.render()

#equip new
#obs,_,_,_ = env.step(77)
#env.render()
#message = bytes(obs['message']).decode('utf-8').rstrip('\x00')
#armor_char = message.split('[')[1].split()[0][-1]
#obs,_,_,_ = env.step(env.actions.index(ord(armor_char)))
#env.render()
# Out:
# You drop a +0 chain mail.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).@.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |[..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:18/** Dx:14 Co:20 In:10 Wi:9 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:10 Xp:1/0

# %%
for item in obs['inv_strs']:
    item = bytes(item).decode('utf-8').rstrip('\x00')
    print(item)
# Out:
# a +1 club (weapon in hand)
# a +2 sling (alternate weapon; not wielded)
# 20 uncursed flint stones (in quiver pouch)
# 24 uncursed rocks
# a +0 chain mail (being worn)
# a golden potion
# 6 yellow potions
# a set of red dragon scales

# %%
for idx,action in enumerate(env.actions):
    print(idx,action)

# %%
ITEM_MAP = {}

def fill_item_map(obs) :
    global ITEM_MAP
    ITEM_MAP = {}
    idx = ord('a')
    for item in obs['inv_strs']:
        item = bytes(item).decode('utf-8').rstrip('\x00')
        if item != '' :
            ITEM_MAP[idx] = item
            idx += 1

def drop_item(str) :
    for key,value in ITEM_MAP.items() :
        if str in value :
            del ITEM_MAP[key]
            return key
        
def add_item(str) :
    item_num= max(ITEM_MAP.keys()) + 1
    ITEM_MAP[item_num] = str

# %%
ITEM_MAP
# Out:
# {97: 'a +1 club (weapon in hand)',
#  98: 'a +2 sling (alternate weapon; not wielded)',
#  99: '20 uncursed flint stones (in quiver pouch)',
#  100: '24 uncursed rocks',
#  102: 'a chain mail',
#  103: 'a golden potion',
#  104: '6 yellow potions',
#  105: 'red dragon scales'}

# %%
ord('f')
# Out:
# 102
