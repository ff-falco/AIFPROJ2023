# %%
import gym
import matplotlib.pyplot as plt
from utils import get_item_index
import numpy as np
import run

# %%
NUM_EPISODES = 5
MAX_STEPS = 100
PATH = 'kb.pl'
RISK_THRESHOLD=50# when the agent feels it's not healthy anymore
MONEY_THRESHOLD=1
MONEY=40
ARROWS= 2
ARROWS_THRESHOLD=4

# %%
des_file,_ = run.completemapdes(1,20)
env = gym.make("MiniHack-Skill-Custom-v0",
                        character="Agent-cav-hum-neu-mal",
                        observation_keys=('screen_descriptions','inv_strs','blstats','message','pixel','chars','inv_oclasses','glyphs'),
                        wizard = True,
                        max_episode_steps = MAX_STEPS ,
                        options =(
                            "color",  # Display color for different monsters, objects, etc
                            "showexp",  # Display the experience points on the status line
                            "nobones",  # Disallow saving and loading bones files
                            "nolegacy",  # Not display an introductory message when starting the game
                            "nocmdassist",  # No command assistance
                            "disclose:+i +a +v +g +c +o",  # End of game prompt replies
                            "runmode:teleport",  # Update the map after movement has finished
                            "mention_walls",  # Give feedback when walking against a wall
                            "nosparkle",  # Not display sparkly effect for resisted magical attacks
                            "showscore",  # Shows approximate accumulated score on the bottom line
                            "race:dwa","gender:mal","align:neu","role:cav",
                            "!autopickup",
                            "pettype:none",
                        ),
                        des_file=des_file,
                )
obs = env.reset(wizkit_items = ['a healing potion','6 potion of confusion'])
env.render()
# Out:
# Hello wizard, welcome to NetHack!  You are a lawful dwarven Caveman.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:19 Co:17 In:8 Wi:8 Ch:6 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:8 Xp:1/0
# Warning: NetHack asked for env variable USER
# Warning: NetHack asked for env variable SPCODER_MAX_RUNTIME

# %%
#27 to drop
#69 takeoff
#77 wear
curr_arm_idx = get_item_index(obs,'leather armor')
print(curr_arm_idx)

#unequip current and drop it
env.step(69)
env.render()
env.step(27)
env.render()
obs,_,_,_ = env.step(env.actions.index(ord('a') + curr_arm_idx))
env.render()

#equip new
obs,_,_,_ = env.step(77)
env.render()
message = bytes(obs['message']).decode('utf-8').rstrip('\x00')
armor_char = message.split('[')[1].split()[0][-1]
obs,_,_,_ = env.step(env.actions.index(ord(armor_char)))
env.render()
# Out:
# 4
#
# You finish taking off your suit.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:15 Co:20 In:8 Wi:12 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:10 Xp:1/0
#
# What do you want to drop? [a-f or ?*]
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:15 Co:20 In:8 Wi:12 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:10 Xp:1/0
#
# You drop an uncursed +0 leather armor.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:15 Co:20 In:8 Wi:12 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:10 Xp:1/0
#
# What do you want to wear? [f or ?*]
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:15 Co:20 In:8 Wi:12 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:10 Xp:1/0
#
# You finish your dressing maneuver.
#
#
#
#
#
#                       ----------------    ---------------
#                       |".........(+...    |............>|
#                       |..........(|--.    |.............|
#                       |.!.).).[.!.|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |.....).....|  .    |.............|
#                       |@..........|  .    |.............|
#                       -------------  .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .    |.............|
#                                      .....+.............|
#                                           ---------------
#
#
# Wizard the Troglodyte          St:17 Dx:15 Co:20 In:8 Wi:12 Ch:7 Lawful S:0
# Dlvl:1 $:0 HP:18(18) Pw:1(1) AC:5 Xp:1/0

# %%
for item in obs['inv_strs']:
    item = bytes(item).decode('utf-8').rstrip('\x00')
    print(item)
# Out:
# a +1 club (weapon in hand)
# a +2 sling (alternate weapon; not wielded)
# 20 uncursed flint stones (in quiver pouch)
# 32 uncursed rocks
# an uncursed +0 leather armor (being worn)
# an orange potion
# 6 dark green potions

# %%
for idx,action in enumerate(env.actions):
    print(idx,action)
# Out:
# 0 CompassDirection.N
# 1 CompassDirection.E
# 2 CompassDirection.S
# 3 CompassDirection.W
# 4 CompassDirection.NE
# 5 CompassDirection.SE
# 6 CompassDirection.SW
# 7 CompassDirection.NW
# 8 CompassDirectionLonger.N
# 9 CompassDirectionLonger.E
# 10 CompassDirectionLonger.S
# 11 CompassDirectionLonger.W
# 12 CompassDirectionLonger.NE
# 13 CompassDirectionLonger.SE
# 14 CompassDirectionLonger.SW
# 15 CompassDirectionLonger.NW
# 16 MiscDirection.DOWN
# 17 MiscDirection.WAIT
# 18 MiscAction.MORE
# 19 Command.ADJUST
# 20 Command.APPLY
# 21 Command.ATTRIBUTES
# 22 Command.CALL
# 23 Command.CAST
# 24 Command.CHAT
# 25 Command.CLOSE
# 26 Command.DIP
# 27 Command.DROP
# 28 Command.DROPTYPE
# 29 Command.EAT
# 30 Command.ENGRAVE
# 31 Command.ENHANCE
# 32 Command.ESC
# 33 Command.FIGHT
# 34 Command.FIRE
# 35 Command.FORCE
# 36 Command.INVENTORY
# 37 Command.INVENTTYPE
# 38 Command.INVOKE
# 39 Command.JUMP
# 40 Command.KICK
# 41 Command.LOOK
# 42 Command.LOOT
# 43 Command.MONSTER
# 44 Command.MOVE
# 45 Command.MOVEFAR
# 46 Command.OFFER
# 47 Command.OPEN
# 48 Command.PAY
# 49 Command.PICKUP
# 50 Command.PRAY
# 51 Command.PUTON
# 52 Command.QUAFF
# 53 Command.QUIVER
# 54 Command.READ
# 55 Command.REMOVE
# 56 Command.RIDE
# 57 Command.RUB
# 58 Command.RUSH
# 59 Command.RUSH2
# 60 Command.SEARCH
# 61 Command.SEEARMOR
# 62 Command.SEERINGS
# 63 Command.SEETOOLS
# 64 Command.SEETRAP
# 65 Command.SEEWEAPON
# 66 Command.SHELL
# 67 Command.SIT
# 68 Command.SWAP
# 69 Command.TAKEOFF
# 70 Command.TAKEOFFALL
# 71 Command.THROW
# 72 Command.TIP
# 73 Command.TURN
# 74 Command.TWOWEAPON
# 75 Command.UNTRAP
# 76 Command.VERSIONSHORT
# 77 Command.WEAR
# 78 Command.WIELD
# 79 Command.WIPE
# 80 Command.ZAP
# 81 TextCharacters.PLUS
# 82 TextCharacters.QUOTE
# 83 TextCharacters.DOLLAR
# 84 TextCharacters.SPACE
